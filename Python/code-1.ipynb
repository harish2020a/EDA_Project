# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df= pd.read_excel("./data-1.xlsx")

# %%
df.head()
# Out:
#    ID          Start time     Completion time      Email  Name  Gender  \
# 0   1 2020-06-12 19:30:33 2020-06-12 19:34:57  anonymous   NaN  Female
# 1   2 2020-06-12 19:29:44 2020-06-12 19:35:19  anonymous   NaN    Male
# 2   3 2020-06-12 19:37:19 2020-06-12 19:40:17  anonymous   NaN  Female
# 3   4 2020-06-12 19:37:18 2020-06-12 19:40:27  anonymous   NaN    Male
# 4   5 2020-06-12 19:37:25 2020-06-12 19:41:49  anonymous   NaN    Male
#
#           Level/Year    Age Your cumulative average (GPA)  \
# 0  Second/ Sophomore  18-24                80-89 / 3-3.49
# 1              Other    +30                    +90 / +3.5
# 2     First/Freshman  18-24                    +90 / +3.5
# 3  Second/ Sophomore  18-24               70-79 / 2.5-299
# 4       Third/Junior  18-24               70-79 / 2.5-299
#
#   Before COVID-19: Which of the following digital tools do you usually use?  \
# 0                                       Mobile phone
# 1                                             Laptop
# ...

# %% [markdown]
# <h1>Data Preprocessing<h1>

# %% [markdown]
# `Renaming columns`

# %%
df.drop(['Start time','Completion time','Email','Name'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    ID  Gender         Level/Year    Age Your cumulative average (GPA)  \
# 0   1  Female  Second/ Sophomore  18-24                80-89 / 3-3.49
# 1   2    Male              Other    +30                    +90 / +3.5
# 2   3  Female     First/Freshman  18-24                    +90 / +3.5
# 3   4    Male  Second/ Sophomore  18-24               70-79 / 2.5-299
# 4   5    Male       Third/Junior  18-24               70-79 / 2.5-299
#
#   Before COVID-19: Which of the following digital tools do you usually use?  \
# 0                                       Mobile phone
# 1                                             Laptop
# 2                                              Other
# 3                                             Laptop
# 4                                             Laptop
#
#   After COVID-19: Which of the following digital tools do you usually use?  \
# 0                                             Laptop
# 1                                             Laptop
# ...

# %%
colname= list(df.columns)

# %%
colname
# Out:
# ['ID',
#  'Gender',
#  'Level/Year',
#  'Age',
#  'Your cumulative average (GPA)',
#  'Before COVID-19: Which of the following digital tools do you usually use?',
#  'After COVID-19: Which of the following digital tools do you usually use?',
#  'Before COVID-19: How much time do you spend using the digital tools in learning?',
#  'After COVID-19: How much time do you spend using the digital tools in learning?',
#  'Before COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.',
#  'After COVID-19: I always use digital tools (mobile, laptop, i-pad) in studying.',
#  'Before COVID-19: When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.',
#  'After COVID-19: When I use the mobile phone, tablet or laptop in e-learning, I cannot concentrate and I am distracted.',
#  'Before COVID-19: I have fixed hours for bedtime and wake-up. ',
#  'After COVID-19: I have fixed hours for bedtime and wake-up. ',
# ...

# %%
newname= ['id', 'sex', 'yr', 'age', 'cgpa', 'bdevice', 'adevice', 'btime', 'atime', 'bdevstudy', 'adevstudy', 'bconc', 'aconc', 'bbed', 'abed', 'baffbed', 'aaffbed',
    'btire', 'atire', 'socdist', 'isolate', 'personality', 'lazy', 'boredom', 'psycho', 'afford', 'unhealthy', 'covidstress', 'devicegpa', 'assgn', 'f2f', 'quiz']

# %%
rename= dict()

for i in range(len(colname)):
    rename[colname[i]]= newname[i]

df.rename(columns= rename, inplace=True)

# %%
df.head()
# Out:
#    id     sex                 yr    age             cgpa       bdevice  \
# 0   1  Female  Second/ Sophomore  18-24   80-89 / 3-3.49  Mobile phone
# 1   2    Male              Other    +30       +90 / +3.5        Laptop
# 2   3  Female     First/Freshman  18-24       +90 / +3.5         Other
# 3   4    Male  Second/ Sophomore  18-24  70-79 / 2.5-299        Laptop
# 4   5    Male       Third/Junior  18-24  70-79 / 2.5-299        Laptop
#
#         adevice btime atime  bdevstudy  ...               lazy  \
# 0        Laptop   6-9  9-12  Uncertain  ...     Strongly Agree
# 1        Laptop  1-3    3-6      Agree  ...        Uncertain\t
# 2  Mobile phone  1-3    3-6   Disagree  ...     Strongly Agree
# 3        Laptop   6-9  1-3   Uncertain  ...  Strongly Disagree
# 4        Laptop  1-3   1-3       Agree  ...        Uncertain\t
#
#           boredom          psycho          afford       unhealthy  \
# 0           Agree  Strongly Agree  Strongly Agree           Agree
# ...
